# %%
from sklearn import metrics

# %%
y_test = [0, 1, 1, 0, 2, 3, 2, 3, 2, 3]
y_pred = [0, 1, 2, 0, 2, 2, 2, 3, 2, 3]

# %%
# Matriz de confusao
print(metrics.confusion_matrix(y_test, y_pred))
# Métricas precisão, recall e F1-score
print(metrics.classification_report(y_test, y_pred, digits=3))
# Out:
# [[2 0 0 0]
#  [0 1 1 0]
#  [0 0 3 0]
#  [0 0 1 2]]
#               precision    recall  f1-score   support
#
#            0      1.000     1.000     1.000         2
#            1      1.000     0.500     0.667         2
#            2      0.600     1.000     0.750         3
#            3      1.000     0.667     0.800         3
#
#     accuracy                          0.800        10
#    macro avg      0.900     0.792     0.804        10
# weighted avg      0.880     0.800     0.798        10
